# %%
# %sql
-- Clean up all tables (Bronze, Silver, Gold)
DELETE FROM logistics_lakehouse.bronze.raw_drivers;
DELETE FROM logistics_lakehouse.bronze.raw_vehicles;
DELETE FROM logistics_lakehouse.bronze.raw_trips;

DELETE FROM logistics_lakehouse.silver.drivers;
DELETE FROM logistics_lakehouse.silver.vehicles;
DELETE FROM logistics_lakehouse.silver.trips;

DELETE FROM logistics_lakehouse.gold.dim_drivers;
DELETE FROM logistics_lakehouse.gold.dim_vehicles;
DELETE FROM logistics_lakehouse.gold.fact_trips;

# %%
# Clear all checkpoint directories for a fresh start
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/bronze_drivers", True)
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/bronze_vehicles", True)
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/bronze_trips", True)
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/silver_drivers", True)
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/silver_vehicles", True)
dbutils.fs.rm("/Volumes/logistics_lakehouse/bronze/checkpoints/silver_trips", True)
